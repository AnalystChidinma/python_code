# %%
import pandas as pd
import os

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\DELL\Documents\Python Tutorial Playground\Notebook
# ['.ipynb_checkpoints', 'notebook.ipynb', 'orders.csv']

# %%
df = pd.read_csv("orders.csv")

# %%
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df.iloc[10] # return the entire info in the dataset
df.iloc[10,1] # return a single value from that dataset
# Out:
# 'Sophie Martin'

# %%
df.describe() # this summarize the distribution of the dataset
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
df[df["Shipped"] == "Yes"] # to retrieve all the shipped products
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 2      1003          Ali Khan       Office Chair    Furniture         1
# 3      1004        Alice Wong          Desk Lamp    Furniture         3
# 5      1006      Nora Ibrahim           Notebook   Stationery         5
# 6      1007       Emily Davis      Standing Desk    Furniture         1
# 8      1009       Maria Rossi                Pen   Stationery        10
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 12     1013       Emma Wilson            Stapler   Stationery         3
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 15     1016      Ahmed Hassan      Printer Paper   Stationery        20
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# ...

# %%
df["Country"] # it index all values inside the country columns
# Out:
# 0              USA
# 1           Canada
# 2              UAE
# 3        Singapore
# 4           Mexico
# 5              UAE
# 6               UK
# 7      South Korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             USA
# 18           Japan
# 19    Saudi Arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South Korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             USA
# 34           Japan
# 35              UK
# 36        Portugal
# 37            Iran
# 38     South Korea
# 39         Ukraine
# Name: Country, dtype: object

# %%
len(df["Country"])
# Out:
# 40

# %%
set(df["Country"]) # to get the set of all the unique values
# Out:
# {'Argentina',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Colombia',
#  'Egypt',
#  'France',
#  'Germany',
#  'India',
#  'Iran',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Pakistan',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'UAE',
#  'UK',
#  'USA',
#  'Ukraine'}

# %%
# to create a new DataFrame which shows the country and product
df[["Country", "Product"]]
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
list(df.iloc[10])
df.iloc[10]
# Out:
# OrderID                  1011
# CustomerName    Sophie Martin
# Product                Webcam
# Category          Electronics
# Quantity                    1
# Price                    85.0
# OrderDate          2024-06-12
# Shipped                   Yes
# Country                France
# Name: 10, dtype: object

# %%
df.iloc[10]["Country"]
# Out:
# 'France'

# %%
df[df["Category"] == "Electronics"]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# 25     1026      Chloe Dubois     Paper Shredder  Electronics         1
# ...

# %%
df[(df["Category"] == "Furniture") & (df["Shipped"] == "Yes")]
# Out:
#     OrderID     CustomerName        Product   Category  Quantity  Price  \
# 2      1003         Ali Khan   Office Chair  Furniture         1  300.0
# 3      1004       Alice Wong      Desk Lamp  Furniture         3   45.0
# 6      1007      Emily Davis  Standing Desk  Furniture         1  450.0
# 19     1020  Fatima Al-Zahra     Whiteboard  Furniture         1  120.0
# 22     1023   Oliver Schmidt   Office Plant  Furniture         2   35.0
# 37     1038   Leila Mansouri       Desk Pad  Furniture         1   28.0
# 39     1040     Anna Ivanova     Desk Clock  Furniture         1   35.0
#
#      OrderDate Shipped       Country
# 2   2024-06-04     Yes           UAE
# 3   2024-06-05     Yes     Singapore
# 6   2024-06-08     Yes            UK
# 19  2024-06-21     Yes  Saudi Arabia
# 22  2024-06-24     Yes       Germany
# 37  2024-07-09     Yes          Iran
# 39  2024-07-11     Yes       Ukraine

# %%
# to check if the category is electronic or the country is USA
df[(df["Category"] == "Electronics") | (df["Country"] == "USA")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
# checking if quantity is greater than 20
df[df["Quantity"] > 20]
# Out:
#     OrderID  CustomerName      Product    Category  Quantity  Price  \
# 33     1034  Alex Johnson  Index Cards  Stationery       100    0.8
#
#      OrderDate Shipped Country
# 33  2024-07-05     Yes     USA

# %%
# Advanced filtering: filter customer name that start with "A"

# %%
df[df["CustomerName"].str.startswith("A")]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity  Price  \
# 2      1003       Ali Khan    Office Chair    Furniture         1  300.0
# 3      1004     Alice Wong       Desk Lamp    Furniture         3   45.0
# 15     1016   Ahmed Hassan   Printer Paper   Stationery        20    8.0
# 16     1017  Anna Kowalski  Wireless Mouse  Electronics         2   45.0
# 30     1031   Amira Hassan         USB Hub  Electronics         1   32.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100    0.8
# 39     1040   Anna Ivanova      Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped    Country
# 2   2024-06-04     Yes        UAE
# 3   2024-06-05     Yes  Singapore
# 15  2024-06-17     Yes      Egypt
# 16  2024-06-18     Yes     Poland
# 30  2024-07-02     Yes    Morocco
# 33  2024-07-05     Yes        USA
# 39  2024-07-11     Yes    Ukraine

# %%
df[df["CustomerName"].str.endswith ("a")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 19     1020   Fatima Al-Zahra         Whiteboard    Furniture         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 39     1040      Anna Ivanova         Desk Clock    Furniture         1
#
#     Price   OrderDate Shipped       Country
# 9    35.0  2024-06-11     Yes         Japan
# 18   15.0  2024-06-20     Yes         Japan
# 19  120.0  2024-06-21     Yes  Saudi Arabia
# 21   95.0  2024-06-23     Yes        Brazil
# 39   35.0  2024-07-11     Yes       Ukraine

# %%
# write a code that extract information from countries that are not in Brazil, USA and Sweden

df[~df["Country"].isin(["USA", "Sweden", "Brazil"])] # combined conditions
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# ...

# %%
# delete and update a specific role
# to update a specific role : locate the role where customer name is Amira Hassan

df.loc[df["Country"] == "USA", "Country"] = "United State"

# %%
df.loc[df["Country"] == "United State"]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped       Country
# 0   2024-06-01     Yes  United State
# 17  2024-06-19      No  United State
# 33  2024-07-05     Yes  United State

# %%
# delete something we have

df = df.drop(39)

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 34     1035   Yuki Yamamoto       Monitor Stand  Electronics         1   55.0
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
#
#      OrderDate Shipped      Country
# 34  2024-07-06     Yes        Japan
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea

# %%
# detect null values in the data or missing value: Data cleaning in pandas
df = df.dropna() # drop any null values in the data
df =df.fillna({"OrderID":0} , inplace = True) # this modify the existing DataFrame without returning any new df

# %%
df = pd.read_csv("orders.csv")

# %%
df.dropna()
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.fillna({"OrderID" : 0} , inplace = True)

# %%
df
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.rename(columns = {"OrderID" : "Order ID"} , inplace = True)

# %%
df
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 3       1004        Alice Wong              Desk Lamp    Furniture         3
# 4       1005     Carlos Mendez               Keyboard  Electronics         2
# 5       1006      Nora Ibrahim               Notebook   Stationery         5
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 8       1009       Maria Rossi                    Pen   Stationery        10
# 9       1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10      1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
# perform a value count on our dataset
df["Country"].value_counts() # this check the product count for each countries
# Out:
# Country
# USA             3
# South Korea     3
# Japan           3
# UK              2
# UAE             2
# Italy           2
# Germany         2
# France          2
# Canada          2
# Iran            1
# Portugal        1
# Colombia        1
# Morocco         1
# Russia          1
# Argentina       1
# Sweden          1
# Pakistan        1
# Egypt           1
# Brazil          1
# Saudi Arabia    1
# Poland          1
# China           1
# Spain           1
# Australia       1
# India           1
# Mexico          1
# Singapore       1
# Ukraine         1
# Name: count, dtype: int64

# %%
# sum the total price of all the products grouped by country
df.groupby("Country")["Price"].sum()
# Out:
# Country
# Argentina         22.0
# Australia         12.0
# Brazil            95.0
# Canada           153.5
# China            280.0
# Colombia          42.0
# Egypt              8.0
# France           160.0
# Germany          175.0
# India            180.0
# Iran              28.0
# Italy             19.5
# Japan            105.0
# Mexico            80.0
# Morocco           32.0
# Pakistan           4.0
# Poland            45.0
# Portugal         125.0
# Russia             2.5
# Saudi Arabia     120.0
# Singapore         45.0
# South Korea      348.0
# Spain             25.0
# Sweden            28.0
# UAE              305.0
# UK               518.0
# USA             1265.8
# Ukraine           35.0
# Name: Price, dtype: float64

# %%
# total price for US
df[df["Country"] =="USA"]["Price"].sum()
# Out:
# np.float64(1265.8)

# %%
df.sort_values("Price", ascending = False)
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 14      1015         Lisa Chen              Bookshelf    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 11      1012         Raj Patel           File Cabinet    Furniture         2
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 31      1032     Thomas Müller       Document Scanner  Electronics         1
# 36      1037     Carlos Santos       Wireless Earbuds  Electronics         1
# 19      1020   Fatima Al-Zahra             Whiteboard    Furniture         1
# 28      1029      Seo-yeon Kim      Wireless Keyboard  Electronics         1
# ...

# %%
# to resave your data after peroforming chnages

df.to_csv("my_file.csv", index = True)

# %%
df= pd.read_csv("my_file.csv")

# %%
df
# Out:
#     Unnamed: 0  Order ID      CustomerName                Product  \
# 0            0      1001        John Smith                 Laptop
# 1            1      1002         Sarah Lee             Headphones
# 2            2      1003          Ali Khan           Office Chair
# 3            3      1004        Alice Wong              Desk Lamp
# 4            4      1005     Carlos Mendez               Keyboard
# 5            5      1006      Nora Ibrahim               Notebook
# 6            6      1007       Emily Davis          Standing Desk
# 7            7      1008        James Park                Monitor
# 8            8      1009       Maria Rossi                    Pen
# 9            9      1010  Takeshi Nakamura                  Mouse
# 10          10      1011     Sophie Martin                 Webcam
# 11          11      1012         Raj Patel           File Cabinet
# 12          12      1013       Emma Wilson                Stapler
# ...
