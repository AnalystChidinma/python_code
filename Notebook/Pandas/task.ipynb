# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\Pandas DF\product_inventory.csv")

# %%
df
# Out:
#     ProductID ProductName     Category  StockQuantity      Supplier  \
# 0        2001      Laptop    Furniture            187     PrimeTech
# 1        2002     Monitor  Electronics            160     PrimeTech
# 2        2003       Chair  Electronics            168     OfficeHub
# 3        2004        Desk  Electronics             51     PrimeTech
# 4        2005       Phone    Furniture            108     PrimeTech
# 5        2006     Monitor    Furniture             16  GlobalSupply
# 6        2007     Monitor  Electronics            153     PrimeTech
# 7        2008      Tablet    Furniture             99    TechSource
# 8        2009      Laptop  Electronics            121     PrimeTech
# 9        2010      Laptop  Electronics             69     PrimeTech
# 10       2011        Desk    Furniture            122     OfficeHub
# 11       2012      Tablet    Furniture             11    TechSource
# 12       2013     Monitor  Electronics            138     PrimeTech
# ...

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'my_file.csv', 'notebook.ipynb', 'orders.csv', 'task.ipynb']

# %%
print(os.getcwd())
# Out:
# C:\Users\DELL\Documents\Python Tutorial Playground\Notebook
